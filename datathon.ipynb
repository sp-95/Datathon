# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame()

# %%
data_attendence = pd.read_csv("Attendence-data.csv")
data_attendence
# Out:
#              Date      Id   In-Time  Out-Time
# 0      2017-06-01  02IYNK   9:25:19  21:24:31
# 1      2017-06-02  02IYNK   9:13:29  18:46:57
# 2      2017-06-05  02IYNK   9:23:36  18:10:33
# 3      2017-06-06  02IYNK   9:29:04  20:10:04
# 4      2017-06-07  02IYNK   9:29:01  20:00:36
# 5      2017-06-08  02IYNK   9:25:04  18:18:27
# 6      2017-06-09  02IYNK   9:30:02  21:57:13
# 7      2017-06-12  02IYNK   9:16:09  18:45:46
# 8      2017-06-13  02IYNK   9:22:00  18:11:17
# 9      2017-06-14  02IYNK   9:28:51  18:11:57
# 10     2017-06-15  02IYNK   9:35:32  21:45:05
# 11     2017-06-16  02IYNK   9:37:59  18:36:57
# 12     2017-06-19  02IYNK   9:22:47  21:26:07
# 13     2017-06-20  02IYNK   9:28:39  21:12:55
# 14     2017-06-21  02IYNK   9:33:38  20:11:11
# 15     2017-06-22  02IYNK   9:26:37  18:11:00
# 16     2017-06-23  02IYNK   9:30:22  21:49:26
# 17     2017-06-26  02IYNK   9:37:08  18:07:09
# 18     2017-06-27  02IYNK   9:23:32  18:55:54
# ...

# %%
data_holiday = pd.read_csv("datathon/Attendance Data - Holiday List.csv")

# %%
dataset=[data_attendence,data_holiday]

# %%
data_attendence.head(0)
# Out:
# Empty DataFrame
# Columns: [Date, Id, In-Time, Out-Time]
# Index: []

# %%
total_employees = np.unique(data_attendence['Id'].values).size

# %%
#ids and their date of presence

# %%
id_presence=data_attendence['Date'].groupby(data_attendence['Id']).size()
id_presence
# Out:
# Id
# 02IYNK    148
# 03QW26     73
# 0BTV9Q     74
# 0EAJQG    134
# 0FFG3X     35
# 0L89RG    130
# 0URRBD    136
# 0ZXYCE     83
# 17V2MZ    123
# 1BHX87    130
# 1KYVZU     65
# 1PJV7L    131
# 1S8VOT    127
# 1T3C0B     62
# 1X3X9H     78
# 20Y6NX     18
# 21Z1E6     22
# 23A612    131
# 2EY7FR     94
# 2FVPJA     74
# 2ZAN8U      2
# 3BHI2G    132
# 3Q476F    126
# 48ANA3     71
# 4BMF46     39
# 4CI5Q9    111
# 4D70JS    126
# 4JZ97G     21
# 4L640C    118
# 4U368R     83
#          ...
# UMW0I8    127
# V0XMBX    112
# V10ZXJ    124
# V1Z5JW    133
# VG6734    133
# VM7IBR     37
# VOLYZ6      5
# VSVRVD    122
# VYPKCZ    129
# VZ4DJN    125
# W5IWP9    138
# W628N1     33
# WATQTR    156
# WC0ZHW    103
# WFVGQL     52
# WIXVRD     62
# WTTZDL     10
# WYAKLM    125
# X4A4QG    136
# XESLPI     73
# XLY618    129
# XQESUE    134
# YNY7VC    132
# YOIIJI    130
# YRASBC      7
# YWFZWB     23
# Z32C7R     80
# ZDN2U3    130
# ZMB29K     28
# ZQR3EB     29
# ...

# %%
year=[]
month=[]
day=[]
for data_date in data_attendence['Date']:
   
    y,m,d=data_date.split("-")
    year.append(y)
    month.append(m)
    day.append(d)
print(year)
# Out:
# ['2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017
# ...

# %%
data_attendence['year']=year
data_attendence['month']=month
data_attendence['day']=day

# %%
df_data_attendence = pd.DataFrame(data_attendence)

# %%
df_data_attendence
# Out:
#              Date      Id   In-Time  Out-Time  year month day
# 0      2017-06-01  02IYNK   9:25:19  21:24:31  2017    06  01
# 1      2017-06-02  02IYNK   9:13:29  18:46:57  2017    06  02
# 2      2017-06-05  02IYNK   9:23:36  18:10:33  2017    06  05
# 3      2017-06-06  02IYNK   9:29:04  20:10:04  2017    06  06
# 4      2017-06-07  02IYNK   9:29:01  20:00:36  2017    06  07
# 5      2017-06-08  02IYNK   9:25:04  18:18:27  2017    06  08
# 6      2017-06-09  02IYNK   9:30:02  21:57:13  2017    06  09
# 7      2017-06-12  02IYNK   9:16:09  18:45:46  2017    06  12
# 8      2017-06-13  02IYNK   9:22:00  18:11:17  2017    06  13
# 9      2017-06-14  02IYNK   9:28:51  18:11:57  2017    06  14
# 10     2017-06-15  02IYNK   9:35:32  21:45:05  2017    06  15
# 11     2017-06-16  02IYNK   9:37:59  18:36:57  2017    06  16
# 12     2017-06-19  02IYNK   9:22:47  21:26:07  2017    06  19
# 13     2017-06-20  02IYNK   9:28:39  21:12:55  2017    06  20
# ...

# %%
id_month_presence=data_attendence['Id'].groupby(data_attendence['day']).size()
id_month_presence
# Out:
# day
# 01    673
# 02    426
# 03    479
# 04    643
# 05    652
# 06    794
# 07    654
# 08    673
# 09    532
# 10    510
# 11    672
# 12    654
# 13    819
# 14    795
# 15    697
# 16    570
# 17    541
# 18    684
# 19    556
# 20    667
# 21    675
# 22    668
# 23    405
# 24    521
# 25    630
# 26    621
# 27    752
# 28    665
# 29    544
# 30    537
# 31    395
# Name: Id, dtype: int64
